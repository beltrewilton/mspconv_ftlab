# %%
# Audio: MSP-Conversation_0021_2_007 | LINE: 12076 | DOMINANCE
# Audio: MSP-Conversation_0055_2_007 | LINE: 8365  | DOMINANCE
# Audio: MSP-Conversation_0130_1_015 | LINE: 2869  | VALENCE
# Audio: MSP-Conversation_0180_1_007 | LINE: 7596  | DOMINANCE
# Audio: MSP-Conversation_0002_1_015 | LINE: 1555  | VALENCE

# %%
import os
os.chdir(os.path.abspath(".."))


import librosa
import pandas as pd
import numpy as np
import warnings
import time
warnings.filterwarnings('ignore')

from src.dataload import load_audio_data, audio_select_mean_vote
from src.emotion_translation import ekman_emotion
from src.metricas import classical_features, get_training_features_simple

# %%
df_annotations = pd.read_excel("data/annotations_2.xlsx")
df_training_audios = pd.read_excel('data/training_audios.xlsx')
df_features_complete = pd.read_csv('data/classic_features_complete.csv')

# %%
start_time = time.time()

# Main loop for audio data
for index, row in df_training_audios.iterrows():
    
    print('Audio:', row['Audio_Name'], ' | Part:', row['Part_Num'])
    print(index , '/', df_training_audios.index.max())
    
    if not pd.isna(row['Done']):
        print('SKIPPED')
        continue
    
    
    # Input
    data, timestamps, sr = load_audio_data(df_annotations, part_num = row['Part_Num'], audio_name = row['Audio_Name'])
    df_input = pd.DataFrame(data = np.stack([timestamps, data]).T, columns = ['Time','Data'])
    
    # Labels
    df_label = audio_select_mean_vote(df_annotations,  part_num = row['Part_Num'], audio_name = row['Audio_Name'])
    df_label['Emotion'] = df_label.apply(lambda row : ekman_emotion(row['Valence'], row['Arousal'], row['Dominance']), axis = 1)
     
    time_index = pd.concat([df_label['Time'],df_input['Time']], ignore_index = True).drop_duplicates().sort_values().reset_index(drop = True)
    df_train = pd.merge(time_index, df_input, how = 'left', on = 'Time')
    df_train = pd.merge(df_train, df_label, how = 'left', on = 'Time')
    
    df_train = df_train.fillna(method='ffill').fillna(method='bfill')
    df_train = df_train.set_index('Time').drop_duplicates().reset_index()
    
    paramaters = {'sr' : sr}
    df_features = get_training_features_simple(classical_features, paramaters, frame_duration = 2.5, start = 0, step = 0.5, df = df_train)
    
    df_features_complete = pd.concat([df_features_complete , df_features])
    
    df_training_audios.loc[index,'Done'] = True 
    
    df_features_complete.to_csv('data/classic_features_complete.csv', index = False)
    df_training_audios.to_excel('data/training_audios.xlsx', index = False)
    
    
end_time = time.time()
print(end_time - start_time)
# Out:
# Audio: MSP-Conversation_0021.wav  | Part: 1
# 0 / 428
# SKIPPED
# Audio: MSP-Conversation_0021.wav  | Part: 2
# 1 / 428
# SKIPPED
# Audio: MSP-Conversation_0021.wav  | Part: 3
# 2 / 428
# SKIPPED
# Audio: MSP-Conversation_0021.wav  | Part: 4
# 3 / 428
# SKIPPED
# Audio: MSP-Conversation_0023.wav  | Part: 1
# 4 / 428
# SKIPPED
# Audio: MSP-Conversation_0023.wav  | Part: 2
# 5 / 428
# SKIPPED
# Audio: MSP-Conversation_0035.wav  | Part: 1
# 6 / 428
# SKIPPED
# Audio: MSP-Conversation_0035.wav  | Part: 2
# 7 / 428
# SKIPPED
# Audio: MSP-Conversation_0043.wav  | Part: 1
# 8 / 428
# SKIPPED
# Audio: MSP-Conversation_0043.wav  | Part: 2
# 9 / 428
# SKIPPED
# Audio: MSP-Conversation_0053.wav  | Part: 1
# 10 / 428
# SKIPPED
# Audio: MSP-Conversation_0053.wav  | Part: 2
# 11 / 428
# SKIPPED
# Audio: MSP-Conversation_0053.wav  | Part: 3
# 12 / 428
# SKIPPED
# Audio: MSP-Conversation_0054.wav  | Part: 1
# 13 / 428
# SKIPPED
# Audio: MSP-Conversation_0054.wav  | Part: 2
# 14 / 428
# SKIPPED
# Audio: MSP-Conversation_0054.wav  | Part: 3
# 15 / 428
# SKIPPED
# Audio: MSP-Conversation_0055.wav  | Part: 1
# 16 / 428
# SKIPPED
# Audio: MSP-Conversation_0055.wav  | Part: 2
# 17 / 428
# SKIPPED
# Audio: MSP-Conversation_0061.wav  | Part: 1
# 18 / 428
# SKIPPED
# Audio: MSP-Conversation_0061.wav  | Part: 2
# 19 / 428
# SKIPPED
# Audio: MSP-Conversation_0067.wav  | Part: 1
# 20 / 428
# SKIPPED
# Audio: MSP-Conversation_0067.wav  | Part: 2
# 21 / 428
# SKIPPED
# Audio: MSP-Conversation_0067.wav  | Part: 3
# 22 / 428
# SKIPPED
# Audio: MSP-Conversation_0079.wav  | Part: 1
# 23 / 428
# SKIPPED
# Audio: MSP-Conversation_0079.wav  | Part: 2
# 24 / 428
# SKIPPED
# Audio: MSP-Conversation_0083.wav  | Part: 1
# 25 / 428
# SKIPPED
# Audio: MSP-Conversation_0083.wav  | Part: 2
# 26 / 428
# SKIPPED
# Audio: MSP-Conversation_0087.wav  | Part: 1
# 27 / 428
# SKIPPED
# Audio: MSP-Conversation_0087.wav  | Part: 2
# 28 / 428
# SKIPPED
# Audio: MSP-Conversation_0087.wav  | Part: 3
# 29 / 428
# SKIPPED
# Audio: MSP-Conversation_0088.wav  | Part: 1
# 30 / 428
# SKIPPED
# Audio: MSP-Conversation_0088.wav  | Part: 2
# 31 / 428
# SKIPPED
# Audio: MSP-Conversation_0094.wav  | Part: 1
# 32 / 428
# SKIPPED
# Audio: MSP-Conversation_0094.wav  | Part: 2
# 33 / 428
# SKIPPED
# Audio: MSP-Conversation_0094.wav  | Part: 3
# 34 / 428
# SKIPPED
# Audio: MSP-Conversation_0101.wav  | Part: 1
# 35 / 428
# SKIPPED
# Audio: MSP-Conversation_0101.wav  | Part: 2
# 36 / 428
# SKIPPED
# Audio: MSP-Conversation_0101.wav  | Part: 3
# 37 / 428
# SKIPPED
# Audio: MSP-Conversation_0101.wav  | Part: 4
# 38 / 428
# SKIPPED
# Audio: MSP-Conversation_0103.wav  | Part: 1
# 39 / 428
# SKIPPED
# Audio: MSP-Conversation_0103.wav  | Part: 2
# 40 / 428
# SKIPPED
# Audio: MSP-Conversation_0103.wav  | Part: 3
# 41 / 428
# SKIPPED
# Audio: MSP-Conversation_0103.wav  | Part: 4
# 42 / 428
# SKIPPED
# Audio: MSP-Conversation_0110.wav  | Part: 1
# 43 / 428
# SKIPPED
# Audio: MSP-Conversation_0110.wav  | Part: 2
# 44 / 428
# SKIPPED
# Audio: MSP-Conversation_0110.wav  | Part: 3
# 45 / 428
# SKIPPED
# Audio: MSP-Conversation_0110.wav  | Part: 4
# 46 / 428
# SKIPPED
# Audio: MSP-Conversation_0125.wav  | Part: 1
# 47 / 428
# SKIPPED
# Audio: MSP-Conversation_0125.wav  | Part: 2
# 48 / 428
# SKIPPED
# Audio: MSP-Conversation_0125.wav  | Part: 3
# 49 / 428
# SKIPPED
# Audio: MSP-Conversation_0130.wav  | Part: 1
# 50 / 428
# SKIPPED
# Audio: MSP-Conversation_0130.wav  | Part: 2
# 51 / 428
# SKIPPED
# Audio: MSP-Conversation_0130.wav  | Part: 3
# 52 / 428
# SKIPPED
# Audio: MSP-Conversation_0130.wav  | Part: 4
# 53 / 428
# SKIPPED
# Audio: MSP-Conversation_0135.wav  | Part: 1
# 54 / 428
# SKIPPED
# Audio: MSP-Conversation_0135.wav  | Part: 2
# 55 / 428
# SKIPPED
# Audio: MSP-Conversation_0140.wav  | Part: 1
# 56 / 428
# SKIPPED
# Audio: MSP-Conversation_0140.wav  | Part: 2
# 57 / 428
# SKIPPED
# Audio: MSP-Conversation_0140.wav  | Part: 3
# 58 / 428
# SKIPPED
# Audio: MSP-Conversation_0147.wav  | Part: 1
# 59 / 428
# SKIPPED
# Audio: MSP-Conversation_0147.wav  | Part: 2
# 60 / 428
# SKIPPED
# Audio: MSP-Conversation_0153.wav  | Part: 1
# 61 / 428
# SKIPPED
# Audio: MSP-Conversation_0153.wav  | Part: 2
# 62 / 428
# SKIPPED
# Audio: MSP-Conversation_0156.wav  | Part: 1
# 63 / 428
# SKIPPED
# Audio: MSP-Conversation_0156.wav  | Part: 2
# 64 / 428
# SKIPPED
# Audio: MSP-Conversation_0156.wav  | Part: 3
# 65 / 428
# SKIPPED
# Audio: MSP-Conversation_0160.wav  | Part: 1
# 66 / 428
# SKIPPED
# Audio: MSP-Conversation_0160.wav  | Part: 2
# 67 / 428
# SKIPPED
# Audio: MSP-Conversation_0166.wav  | Part: 1
# 68 / 428
# SKIPPED
# Audio: MSP-Conversation_0166.wav  | Part: 2
# 69 / 428
# SKIPPED
# Audio: MSP-Conversation_0172.wav  | Part: 1
# 70 / 428
# SKIPPED
# Audio: MSP-Conversation_0172.wav  | Part: 2
# 71 / 428
# SKIPPED
# Audio: MSP-Conversation_0180.wav  | Part: 1
# 72 / 428
# 0.5 / 329.8738
# 1.0 / 329.8738
# 1.5 / 329.8738
# 2.0 / 329.8738
# 2.5 / 329.8738
# 3.0 / 329.8738
# 3.5 / 329.8738
# 4.0 / 329.8738
# 4.5 / 329.8738
# 5.0 / 329.8738
# 5.5 / 329.8738
# 6.0 / 329.8738
# 6.5 / 329.8738
# 7.0 / 329.8738
# 7.5 / 329.8738
# 8.0 / 329.8738
# 8.5 / 329.8738
# 9.0 / 329.8738
# 9.5 / 329.8738
# 10.0 / 329.8738
# 10.5 / 329.8738
# 11.0 / 329.8738
# 11.5 / 329.8738
# 12.0 / 329.8738
# 12.5 / 329.8738
# 13.0 / 329.8738
# 26.5 / 305.0427
# 27.0 / 305.0427
# 27.5 / 305.0427
# 28.0 / 305.0427
# 28.5 / 305.0427
# 29.0 / 305.0427
# 29.5 / 305.0427
# 30.0 / 305.0427
# 30.5 / 305.0427
# 31.0 / 305.0427
# 31.5 / 305.0427
# 32.0 / 305.0427
# 32.5 / 305.0427
# 33.0 / 305.0427
# 33.5 / 305.0427
# 34.0 / 305.0427
# 34.5 / 305.0427
# 35.0 / 305.0427
# 35.5 / 305.0427
# 36.0 / 305.0427
# 36.5 / 305.0427
# 37.0 / 305.0427
# 37.5 / 305.0427
# 38.0 / 305.0427
# 38.5 / 305.0427
# 39.0 / 305.0427
# 39.5 / 305.0427
# 40.0 / 305.0427
# 40.5 / 305.0427
# 41.0 / 305.0427
# 41.5 / 305.0427
# 42.0 / 305.0427
# 42.5 / 305.0427
# 43.0 / 305.0427
# 43.5 / 305.0427
# 44.0 / 305.0427
# 44.5 / 305.0427
# 45.0 / 305.0427
# 45.5 / 305.0427
# 46.0 / 305.0427
# 46.5 / 305.0427
# 47.0 / 305.0427
# 47.5 / 305.0427
# 48.0 / 305.0427
# 48.5 / 305.0427
# 49.0 / 305.0427
# 49.5 / 305.0427
# 50.0 / 305.0427
# 50.5 / 305.0427
# 51.0 / 305.0427
# 51.5 / 305.0427
# 52.0 / 305.0427
# 52.5 / 305.0427
# 53.0 / 305.0427
# 53.5 / 305.0427
# 54.0 / 305.0427
# 54.5 / 305.0427
# 55.0 / 305.0427
# 55.5 / 305.0427
# 56.0 / 305.0427
# 56.5 / 305.0427
# 57.0 / 305.0427
# 57.5 / 305.0427
# 58.0 / 305.0427
# 58.5 / 305.0427
# 59.0 / 305.0427
# 59.5 / 305.0427
# 60.0 / 305.0427
# 60.5 / 305.0427
# 61.0 / 305.0427
# 61.5 / 305.0427
# 62.0 / 305.0427
# 62.5 / 305.0427
# 63.0 / 305.0427
# 63.5 / 305.0427
# 64.0 / 305.0427
# 64.5 / 305.0427
# 65.0 / 305.0427
# 65.5 / 305.0427
# 66.0 / 305.0427
# 66.5 / 305.0427
# 67.0 / 305.0427
# 67.5 / 305.0427
# 68.0 / 305.0427
# 68.5 / 305.0427
# 69.0 / 305.0427
# 69.5 / 305.0427
# 70.0 / 305.0427
# 70.5 / 305.0427
# 71.0 / 305.0427
# 71.5 / 305.0427
# 72.0 / 305.0427
# 72.5 / 305.0427
# 73.0 / 305.0427
# 73.5 / 305.0427
# 74.0 / 305.0427
# 74.5 / 305.0427
# 75.0 / 305.0427
# 75.5 / 305.0427
# 76.0 / 305.0427
# 76.5 / 305.0427
# 77.0 / 305.0427
# 77.5 / 305.0427
# 78.0 / 305.0427
# 78.5 / 305.0427
# 79.0 / 305.0427
# 79.5 / 305.0427
# 80.0 / 305.0427
# 80.5 / 305.0427
# 81.0 / 305.0427
# 81.5 / 305.0427
# 82.0 / 305.0427
# 82.5 / 305.0427
# 83.0 / 305.0427
# 83.5 / 305.0427
# 84.0 / 305.0427
# 84.5 / 305.0427
# 85.0 / 305.0427
# 85.5 / 305.0427
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 30
#      27 df_train = df_train.set_index('Time').drop_duplicates().reset_index()
#      29 paramaters = {'sr' : sr}
# ---> 30 df_features = get_training_features_simple(classical_features, paramaters, frame_duration = 2.5, start = 0, step = 0.5, df = df_train)
#      32 df_features_complete = pd.concat([df_features_complete , df_features])
#      34 df_training_audios.loc[index,'Done'] = True
#
# File ~\Documents\GitHub\mspconv_ftlab\src\metricas.py:68, in get_training_features_simple(feature_function, feature_function_parameters, frame_duration, start, step, df)
#      64 while start + 2.5 < end:
#      66     df_frame = df[(df['Time'] >= start) & (df['Time'] <= start + frame_duration)]
# ---> 68     feature = feature_function(df['Data'].values, feature_function_parameters['sr'])
#      69     emotion = df_frame.groupby('Emotion').count().sort_values(by = 'Time', ascending = False).reset_index().loc[0,'Emotion']
#      70     a, d, v = df_frame[['Arousal','Dominance','Valence']].mean()
#
# File ~\Documents\GitHub\mspconv_ftlab\src\metricas.py:28, in classical_features(data, sample_rate)
#      26 # Chroma_stft
#      27 stft = np.abs(librosa.stft(data))
# ---> 28 chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
#      29 result = np.hstack((result, chroma_stft)) # stacking horizontally
#      31 # MFCC
#
# File ~\Anaconda3\envs\SER\lib\site-packages\librosa\feature\spectral.py:1273, in chroma_stft(y, sr, S, norm, n_fft, hop_length, win_length, window, center, pad_mode, tuning, n_chroma, **kwargs)
#    1260 S, n_fft = _spectrogram(
#    1261     y=y,
#    1262     S=S,
#    (...)
#    1269     pad_mode=pad_mode,
#    1270 )
#    1272 if tuning is None:
# -> 1273     tuning = estimate_tuning(S=S, sr=sr, bins_per_octave=n_chroma)
#    1275 # Get the filter bank
#    1276 chromafb = filters.chroma(
#    1277     sr=sr, n_fft=n_fft, tuning=tuning, n_chroma=n_chroma, **kwargs
#    1278 )
#
# File ~\Anaconda3\envs\SER\lib\site-packages\librosa\core\pitch.py:91, in estimate_tuning(y, sr, S, n_fft, resolution, bins_per_octave, **kwargs)
#      24 def estimate_tuning(
#      25     *,
#      26     y: Optional[np.ndarray] = None,
#    (...)
#      32     **kwargs: Any,
#      33 ) -> float:
#      34     """Estimate the tuning of an audio time series or spectrogram input.
#      35
#      36     Parameters
#    (...)
#      89     -0.08000000000000002
#      90     """
# ---> 91     pitch, mag = piptrack(y=y, sr=sr, S=S, n_fft=n_fft, **kwargs)
#      93     # Only count magnitude where frequency is > 0
#      94     pitch_mask = pitch > 0
#
# File ~\Anaconda3\envs\SER\lib\site-packages\librosa\core\pitch.py:354, in piptrack(y, sr, S, n_fft, hop_length, fmin, fmax, threshold, win_length, window, center, pad_mode, ref)
#     351     ref_value = np.abs(ref)
#     353 # Store pitch and magnitude
# --> 354 idx = np.nonzero(freq_mask & util.localmax(S * (S > ref_value), axis=-2))
#     355 pitches[idx] = (idx[-2] + shift[idx]) * float(sr) / n_fft
#     356 mags[idx] = S[idx] + dskew[idx]
#
# KeyboardInterrupt:
